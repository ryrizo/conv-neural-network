# %%
import pickle

def unpickle(file):
    import cPickle
    fo = open(file, 'rb')
    dict = cPickle.load(fo)
    fo.close()
    return dict

data = unpickle('C:\Users\Ryan\Documents\Machine Learning\conv-neural-network\cifar-10-python\cifar-10-batches-py\data_batch_1')

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# ['data', 'labels', 'batch_label', 'filenames']

# %%
type(data['data'])
# Out:
# numpy.ndarray

# %%
image_batch = data['data']
label_batch = data['labels']

# %%
image_batch[0]
# Out:
# array([ 59,  43,  50, ..., 140,  84,  72], dtype=uint8)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %matplotlib inline
im = np.reshape(image_batch[8], (32,32,3), order='F')
img = plt.imshow(im)

# %%
print label_names.get('label_names')[label_batch[8]]
# Out:
# ship

# %%
label_names = unpickle('C:\\Users\\Ryan\\Documents\\Machine Learning\\conv-neural-network\\cifar-10-python\\cifar-10-batches-py\\batches.meta')

# %%
label_names
# Out:
# {'label_names': ['airplane',
#   'automobile',
#   'bird',
#   'cat',
#   'deer',
#   'dog',
#   'frog',
#   'horse',
#   'ship',
#   'truck'],
#  'num_cases_per_batch': 10000,
#  'num_vis': 3072}

# %%
test_data = unpickle('C:\\Users\\Ryan\\Documents\\Machine Learning\\conv-neural-network\\cifar-10-python\\cifar-10-batches-py\\test_batch')
test_labels = test_data['labels']

# %%
len(test_labels)
# Out:
# 10000

# %%
from sklearn.metrics import accuracy_score
import random

baseline_1 = [1] * 10000
baseline_rand = list()
for i in range(0,10000):
    baseline_rand.append(random.randint(0,9))
score = accuracy_score(test_labels, baseline_1)
score2 = accuracy_score(test_labels, baseline_rand)

# %%
score
# Out:
# 0.10000000000000001

# %%
score2
# Out:
# 0.0969
